# %%
import matplotlib.pyplot  as plt
years = [2010, 2011, 2012, 2013, 2014]
sales = [200, 300, 450, 350, 500]
p = [250, 150, 360, 400, 450]
plt.plot(years,sales,color='red',lw=3)
plt.fill_between(years,sales,p,interpolate=True,where=sales > p,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\python\IPE SEM-4\ex.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/d%3A/python/IPE%20SEM-4/ex.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> p = [250, 150, 360, 400, 450]
#       <a href='vscode-notebook-cell:/d%3A/python/IPE%20SEM-4/ex.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(years,sales,color='red',lw=3)
# ----> <a href='vscode-notebook-cell:/d%3A/python/IPE%20SEM-4/ex.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> plt.fill_between(years,sales,p,interpolate=True,where=sales > p,)
#       <a href='vscode-notebook-cell:/d%3A/python/IPE%20SEM-4/ex.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> plt.show()
#
# File c:\Users\divye\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2571, in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2567 @_copy_docstring_and_deprecators(Axes.fill_between)
# ...
